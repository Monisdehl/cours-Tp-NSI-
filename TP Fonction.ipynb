# %% [markdown]
# # Exercice 1
#
# Déterminez les renvois des fonctions $f$ et $g$ définies ci-dessous pour les appels $f(2),f(0),g(1)$ et $g(3)$.

# %%
def f(x):
    y = x**2-3
    return y

def g(x):
    y = x**2 - 3
    z = 3*x -y
    y = z + x
    return z

# %% [markdown]
# # Exercice 2
#
# On considère les trois fonctions Python suivantes.
#
# Détaillez les calculs de $f1(5,1)$, $f2(5,1)$ et $f3(5,1)$. Vous listerez l’ensemble de toutes les affectations qui sont réalisées en indiquant si celles-ci ont lieu :
# * avant le début de la boucle ;
# * dans la boucle et, dans ce cas, au combientième tour de la boucle ;
# * après la sortie de la boucle.

# %%
def f1(x,y):#avant boucle
    z = 0#avant boucle
    while z<20:#debut boucle
        z = x+y#dans boucle tour:1
        x = 2*x#dans boucle tour:2
        y = 3*y#dans boucle tour:3
        z = y*z#dans boucle tour:4
        
    return z# apres boucle

def f2(x,y):#avant boucle
    z = 0#avant boucle
    while z < 20:#debut boucle
        z = x + y#dans boucle tour:1
        x = 2*x#dans boucle tour:2
        y = 3*y#dans boucle tour:3
    x = y*z# apres boucle 
    return z# apres boucle 

def f3(x,y):#avant boucle
    z = 0#avant boucle
    while z < 20:#debut boucle
        z = x + y#dans boucle tour:1
    x = 2*x# apres boucle
    y = 3*y# apres boucle
    return z# apres boucle

# %% [markdown]
# # Exercice 3
#
# Le tableau suivant donne la mention en fonction de la note N obtenue à la première session du baccalauréat.
#
# |Condition | Mention|
# |---|---|
# |$0\leq N <8$ | Ajournée |
# |$8 \leq N <10$ | Rattrapage |
# |$10 \leq N < 12$ | Sans Mention |
# |$12 \leq N < 14$ | Assez Bien |
# |$14 \leq N < 16$ | Bien|
# |$N \geq 16$ |Très bien |
#
# Définissez une fonction Python qui prend une note en paramètre et renvoie la men-
# tion correspondante sous forme de chaîne de caractère.

# %%
N=int(input("ta note:"))
def mention(N):
    if 0<=N<8:
        print("Ajournée")
    elif 8<=N<10:
        print("Rattrapage")
    elif 10<=N<12:
        print("Sans Mention")
    elif 12<=N<14:
        print("Assez Bien")
    elif 14<=N<16:
        print("Bien")
    elif N>16:
        print("Très Bien")
    
mention(N)
# Out:
# Très Bien

# %% [markdown]
# # Exercice 4
#
# 1. Recopiez et complétez le code suivant de la fonction <code> lancer </code> pour qu'elle simule le lancer d'un dé équilibré à six faces.
# ```
#         import random as rd
#
#         def lancer():
#             return rd.randint(...,...)
# ```
# 2. On souhaite réaliser une simulation du lancer de 1000 dés. Complétez le code
# suivant et exécutez le à la suite du code précédent afin de pouvoir remplir le
# tableau des effectifs correspondant à la série statistique de la simulation.

# %%
import random as rd
def lancer():
    print(rd.randint(1,6))
lancer()
# Out:
# 6

# %%
import random as rd
def lancer():
    print(rd.randint(1,6))

def lancer_1000():
    for i in range(1000):
        lancer()
lancer_1000()
# Out:
# 4
# 2
# 1
# 4
# 6
# 2
# 5
# 2
# 3
# 1
# 6
# 2
# 2
# 4
# 6
# 4
# 2
# 6
# 1
# 5
# 4
# 1
# 4
# 5
# 6
# 2
# 3
# 3
# 2
# 3
# 5
# 2
# 5
# 1
# 1
# 1
# 4
# 2
# 3
# 3
# 6
# 1
# 5
# 3
# 3
# 5
# 2
# 4
# 1
# 2
# 4
# 1
# 1
# 3
# 5
# 1
# 2
# 5
# 4
# 6
# 4
# 6
# 6
# 1
# 2
# 2
# 6
# 5
# 4
# 1
# 3
# 5
# 6
# 6
# 3
# 3
# 2
# 5
# 6
# 4
# 4
# 6
# 4
# 3
# 6
# 6
# 1
# 6
# 2
# 4
# 5
# 6
# 6
# 3
# 5
# 1
# 1
# 6
# 2
# 1
# 1
# 4
# 5
# 4
# 4
# 3
# 6
# 6
# 2
# 2
# 5
# 5
# 1
# 3
# 2
# 6
# 1
# 6
# 1
# 3
# 4
# 1
# 5
# 5
# 5
# 6
# 5
# 1
# 4
# 1
# 1
# 1
# 4
# 6
# 6
# 1
# 1
# 1
# 1
# 2
# 6
# 6
# 5
# 5
# 2
# 5
# 2
# 1
# 6
# 4
# 1
# 4
# 6
# 5
# 6
# 2
# 2
# 2
# 6
# 5
# 2
# 2
# 1
# 2
# 4
# 1
# 3
# 6
# 1
# 3
# 3
# 6
# 5
# 4
# 5
# 1
# 4
# 2
# 1
# 1
# 3
# 1
# 6
# 1
# 2
# 4
# 1
# 3
# 3
# 6
# 6
# 1
# 3
# 5
# 2
# 6
# 2
# 2
# 1
# 5
# 4
# 4
# 4
# 4
# 4
# 2
# 2
# 2
# 2
# 1
# 3
# 5
# 2
# 6
# 5
# 4
# 6
# 6
# 3
# 2
# 4
# 4
# 3
# 3
# 5
# 1
# 4
# 5
# 3
# 4
# 5
# 2
# 4
# 6
# 2
# 3
# 5
# 2
# 6
# 1
# 3
# 5
# 3
# 2
# 3
# 3
# 5
# 2
# 4
# 4
# 2
# 1
# 6
# 2
# 3
# 3
# 2
# 4
# 2
# 3
# 3
# 5
# 4
# 6
# 5
# 3
# 2
# 3
# 3
# 1
# 4
# 1
# 1
# 6
# 5
# 4
# 2
# 6
# 3
# 4
# 4
# 5
# 3
# 4
# 4
# 3
# 4
# 2
# 3
# 1
# 6
# 4
# 4
# 6
# 2
# 4
# 4
# 4
# 2
# 5
# 2
# 1
# 3
# 1
# 5
# 4
# 2
# 3
# 1
# 5
# 1
# 3
# 1
# 5
# 1
# 3
# 3
# 6
# 5
# 6
# 5
# 5
# 3
# 3
# 5
# 1
# 6
# 1
# 6
# 4
# 6
# 1
# 2
# 4
# 1
# 2
# 3
# 1
# 1
# 2
# 6
# 1
# 5
# 1
# 6
# 1
# 2
# 4
# 5
# 4
# 1
# 2
# 2
# 1
# 3
# 4
# 5
# 4
# 4
# 2
# 6
# 6
# 6
# 2
# 6
# 1
# 6
# 5
# 2
# 6
# 5
# 1
# 2
# 2
# 1
# 6
# 3
# 2
# 4
# 3
# 3
# 2
# 4
# 6
# 1
# 4
# 4
# 1
# 5
# 2
# 5
# 3
# 2
# 6
# 3
# 2
# 6
# 1
# 5
# 6
# 1
# 4
# 1
# 3
# 4
# 4
# 1
# 1
# 5
# 4
# 2
# 3
# 5
# 1
# 3
# 6
# 2
# 4
# 6
# 2
# 4
# 5
# 1
# 5
# 5
# 3
# 2
# 1
# 5
# 6
# 2
# 5
# 2
# 1
# 6
# 5
# 3
# 6
# 4
# 4
# 1
# 6
# 5
# 1
# 4
# 4
# 6
# 4
# 2
# 4
# 1
# 4
# 6
# 2
# 6
# 6
# 6
# 2
# 1
# 5
# 3
# 3
# 2
# 5
# 5
# 2
# 4
# 2
# 5
# 5
# 1
# 1
# 1
# 4
# 3
# 5
# 5
# 6
# 6
# 3
# 3
# 2
# 4
# 2
# 5
# 2
# 5
# 1
# 3
# 5
# 6
# 3
# 3
# 5
# 5
# 5
# 3
# 4
# 5
# 4
# 6
# 2
# 6
# 6
# 4
# 4
# 2
# 5
# 5
# 5
# 3
# 2
# 2
# 4
# 5
# 2
# 5
# 5
# 1
# 3
# 2
# 1
# 4
# 2
# 5
# 2
# 3
# 2
# 1
# 5
# 3
# 4
# 5
# 3
# 6
# 3
# 1
# 2
# 3
# 3
# 6
# 5
# 4
# 4
# 4
# 6
# 3
# 4
# 3
# 1
# 1
# 2
# 5
# 3
# 4
# 3
# 5
# 1
# 4
# 1
# 1
# 2
# 6
# 2
# 2
# 4
# 5
# 4
# 3
# 6
# 6
# 5
# 2
# 3
# 2
# 2
# 5
# 6
# 5
# 4
# 3
# 2
# 5
# 6
# 3
# 3
# 1
# 1
# 6
# 5
# 4
# 1
# 1
# 4
# 2
# 4
# 1
# 3
# 3
# 1
# 5
# 2
# 4
# 4
# 2
# 1
# 3
# 3
# 4
# 6
# 1
# 4
# 3
# 5
# 1
# 4
# 3
# 3
# 2
# 2
# 4
# 6
# 3
# 4
# 4
# 1
# 2
# 4
# 5
# 4
# 1
# 5
# 1
# 5
# 6
# 4
# 5
# 3
# 5
# 2
# 4
# 2
# 1
# 2
# 2
# 2
# 6
# 4
# 4
# 3
# 4
# 5
# 3
# 3
# 6
# 4
# 6
# 4
# 5
# 4
# 2
# 2
# 4
# 5
# 2
# 3
# 6
# 5
# 3
# 6
# 5
# 1
# 1
# 1
# 2
# 5
# 4
# 5
# 3
# 2
# 3
# 6
# 5
# 2
# 3
# 3
# 4
# 2
# 2
# 3
# 6
# 5
# 6
# 6
# 6
# 5
# 2
# 3
# 1
# 2
# 6
# 3
# 2
# 1
# 4
# 4
# 2
# 5
# 4
# 2
# 4
# 2
# 3
# 5
# 4
# 3
# 1
# 3
# 1
# 3
# 6
# 3
# 6
# 1
# 5
# 3
# 6
# 5
# 3
# 4
# 5
# 6
# 4
# 2
# 1
# 2
# 1
# 1
# 6
# 5
# 3
# 4
# 4
# 5
# 4
# 1
# 1
# 3
# 4
# 6
# 1
# 5
# 1
# 3
# 3
# 5
# 5
# 2
# 5
# 1
# 3
# 1
# 6
# 2
# 1
# 4
# 3
# 1
# 4
# 5
# 4
# 3
# 2
# 5
# 3
# 4
# 3
# 1
# 5
# 2
# 3
# 1
# 1
# 2
# 6
# 6
# 1
# 6
# 2
# 5
# 6
# 5
# 2
# 4
# 4
# 4
# 3
# 3
# 2
# 5
# 3
# 2
# 1
# 3
# 3
# 2
# 1
# 3
# 3
# 6
# 3
# 4
# 6
# 4
# 3
# 5
# 5
# 3
# 4
# 5
# 6
# 6
# 5
# 6
# 5
# 3
# 3
# 4
# 4
# 2
# 3
# 2
# 5
# 3
# 2
# 5
# 1
# 4
# 2
# 3
# 1
# 4
# 1
# 3
# 1
# 5
# 6
# 5
# 2
# 3
# 2
# 2
# 2
# 1
# 5
# 2
# 5
# 3
# 3
# 5
# 5
# 6
# 4
# 6
# 5
# 2
# 2
# 6
# 1
# 4
# 6
# 1
# 6
# 6
# 1
# 6
# 2
# 1
# 5
# 1
# 1
# 3
# 4
# 6
# 4
# 2
# 5
# 3
# 4
# 1
# 1
# 5
# 2
# 3
# 4
# 4
# 3
# 5
# 5
# 5
# 1
# 6
# 2
# 4
# 2
# 3
# 6
# 4
# 6
# 1
# 4
# 4
# 5
# 2
# 5
# 3
# 5
# 5
# 1
# 1
# 1
# 4
# 1
# 2
# 5
# 2
# 1
# 4
# 2
# 4
# 3
# 2
# 5
# 5
# 1
# 6
# 2
# 5
# 6
# 3
# 5
# 3
# 3
# 1
# 3
# 3
# 4
# 1
# 3
# 5
# 4
# 6
# 5
# 3
# 3
# 1
# 1
# 3
# 3
# 3
# 2
# 5
# 2
# 3
# 5
# 3
# 6
# 5
# 3
# 3
# 5
# 2
# 5
# 2
# 6
# 1
# 6
# 3
# 2
# 5
# 5
# 1
# 2
# 2
# 3
# 3
# 6
# 1
# 4
# 3
# 6
# 5
# 3
# 2
# 5
# 3
# 5
# 1
# 6
# 6
